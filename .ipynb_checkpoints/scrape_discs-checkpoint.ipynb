# %%
# import dependencies 
from bs4 import BeautifulSoup as bs
import requests
import pymongo
import pandas as pd
from splinter import Browser
import time
# from urllib.request import urlopen

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# conn = 'mongodb://localhost:27017'
# client = pymongo.MongoClient(conn)

# %%
# db = client.disc_golf_db
# collection = db.innovadics

# %%
# url = 'https://www.innovadiscs.com/disc/'

# https://www.innovadiscs.com/home/disc-golf-faq/plastic-types-overview/
# this is the url to get data on the plastics

# %%
disc_name = []
disc_url = []
disc_flight_ratings = []
disc_description = []

for x in range(1,13):
    url = f'https://www.innovadiscs.com/disc/page/{x}/'
    browser.visit(url)
    time.sleep(5)
    html = browser.html
    soup = bs(html, 'html.parser')
    disc_html = soup.find_all('div', class_ = 'entry-block')

    for disc in disc_html:
        name = disc.find('a').get_text()
        disc_name.append(name)
        url = disc.find('a')['href']
        disc_url.append(url)
        try:
            flight_rating = disc.find('span').get_text()
        except:
            flight_rating = "Not Available"
        disc_flight_ratings.append(flight_rating)
        description = disc.find('p').get_text()
        disc_description.append(description)
        
    print(f"Page {x} is complete")

    #    post = {
    #        "Disc Name" : disc_name,
    #        "Disc URL" : disc_url,
    #        "Disc Flight Ratings" : disc_flight_ratings,
    #    }

    #    collection.insert_one(post)
# Out:
# Page 1 is complete
# Page 2 is complete
# Page 3 is complete
# Page 4 is complete
# Page 5 is complete
# Page 6 is complete
# Page 7 is complete
# Page 8 is complete
# Page 9 is complete
# Page 10 is complete
# Page 11 is complete
# Page 12 is complete

# %%
columns = ["Disc Name", "Disc URL", "Disc Flight Ratings", "Disc Description"]

innova_disc_db = pd.DataFrame(columns=columns)

innova_disc_db["Disc Name"] = disc_name
innova_disc_db["Disc URL"] = disc_url
innova_disc_db["Disc Flight Raitings"]= disc_flight_ratings
innova_disc_db["Disc Description"] = disc_description

# %%
innova_disc_db
# Out:
#       Disc Name                                      Disc URL  \
# 0          Aero        https://www.innovadiscs.com/disc/aero/
# 1           Ape         https://www.innovadiscs.com/disc/ape/
# 2     Archangel   https://www.innovadiscs.com/disc/archangel/
# 3        Archon      https://www.innovadiscs.com/disc/archon/
# 4         Atlas       https://www.innovadiscs.com/disc/atlas/
# ..          ...                                           ...
# 107      Wraith      https://www.innovadiscs.com/disc/wraith/
# 108    XCaliber    https://www.innovadiscs.com/disc/xcaliber/
# 109          XD          https://www.innovadiscs.com/disc/xd/
# 110  Yeti Aviar  https://www.innovadiscs.com/disc/yeti-aviar/
# 111      Zephyr      https://www.innovadiscs.com/disc/zephyr/
#
#     Disc Flight Ratings                                   Disc Description  \
# 0                   NaN  The Aero is a great disc for new players. It's...
# 1                   NaN  A fast long-range distance driver with great s...
# 2                   NaN  The Archangel is a turnover driver that maximi...
# 3                   NaN  The Archon is a speed 11 distance driver remin...
# 4                   NaN  The Atlas is an overmold Mid-Range with a smal...
# ..                  ...                                                ...
# 107                 NaN  The Wraith is a long and fast distance driver....
# 108                 NaN  The XCaliber is for those who have got to have...
# 109                 NaN  The XD has a low profile grip which is secure ...
# 110                 NaN  The Yeti Aviar is for Big Bead Aviar lovers lo...
# 111                 NaN  The Zephyr is a throw and catch disc. It has l...
#
#     Disc Flight Raitings
# 0      [ 3 | 6 | 0 | 0 ]
# 1     [ 13 | 5 | 0 | 4 ]
# 2     [ 8 | 6 | -4 | 1 ]
# 3    [ 11 | 5 | -2 | 2 ]
# 4      [ 5 | 4 | 0 | 1 ]
# ..                   ...
# 107  [ 11 | 5 | -1 | 3 ]
# 108   [ 12 | 5 | 0 | 4 ]
# 109   [ 3 | 4 | -1 | 1 ]
# 110    [ 2 | 3 | 0 | 1 ]
# 111        Not Available
#
# [112 rows x 5 columns]

# %%
del innova_disc_db["Disc Flight Ratings"]
innova_disc_db
# Out:
#       Disc Name                                      Disc URL  \
# 0          Aero        https://www.innovadiscs.com/disc/aero/
# 1           Ape         https://www.innovadiscs.com/disc/ape/
# 2     Archangel   https://www.innovadiscs.com/disc/archangel/
# 3        Archon      https://www.innovadiscs.com/disc/archon/
# 4         Atlas       https://www.innovadiscs.com/disc/atlas/
# ..          ...                                           ...
# 107      Wraith      https://www.innovadiscs.com/disc/wraith/
# 108    XCaliber    https://www.innovadiscs.com/disc/xcaliber/
# 109          XD          https://www.innovadiscs.com/disc/xd/
# 110  Yeti Aviar  https://www.innovadiscs.com/disc/yeti-aviar/
# 111      Zephyr      https://www.innovadiscs.com/disc/zephyr/
#
#                                       Disc Description Disc Flight Raitings
# 0    The Aero is a great disc for new players. It's...    [ 3 | 6 | 0 | 0 ]
# 1    A fast long-range distance driver with great s...   [ 13 | 5 | 0 | 4 ]
# 2    The Archangel is a turnover driver that maximi...   [ 8 | 6 | -4 | 1 ]
# 3    The Archon is a speed 11 distance driver remin...  [ 11 | 5 | -2 | 2 ]
# 4    The Atlas is an overmold Mid-Range with a smal...    [ 5 | 4 | 0 | 1 ]
# ..                                                 ...                  ...
# 107  The Wraith is a long and fast distance driver....  [ 11 | 5 | -1 | 3 ]
# 108  The XCaliber is for those who have got to have...   [ 12 | 5 | 0 | 4 ]
# 109  The XD has a low profile grip which is secure ...   [ 3 | 4 | -1 | 1 ]
# 110  The Yeti Aviar is for Big Bead Aviar lovers lo...    [ 2 | 3 | 0 | 1 ]
# 111  The Zephyr is a throw and catch disc. It has l...        Not Available
#
# [112 rows x 4 columns]

# %%
# speed classification
# Putt & Approach speed 1 to 3
# Mid-Distance/Fairway speed 4 to 8
# Driver speed 9 to 14
disc_classification = []
import re
for disc in disc_flight_ratings:
    split = re.split("[ | ] | | ", disc)
    if split[1] == "Available":
        disc_classification.append("Ultimate, Recreation, & Specialty")
    elif float(split[1]) > 0 and float(split[1]) < 4:
        disc_classification.append("Putt & Approach")
    elif float(split[1]) > 3 and float(split[1]) < 9:
        disc_classification.append("Mid-Distance/Fairway")
    elif float(split[1]) > 8 and float(split[1]) < 15:
        disc_classification.append("Driver")

# %%
innova_disc_db["Disc Classification"] = disc_classification

# %%
innova_disc_db.to_csv("data/innova_disc_db.csv")
